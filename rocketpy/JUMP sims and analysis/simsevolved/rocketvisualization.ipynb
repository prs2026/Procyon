# %%
from rocketpy import Environment, SolidMotor, Rocket, Flight, Function

import csv
import pandas as pds

from rocketdefintions import JUMPStack,JUMPSustainer,JUMPSustainerNOMOTOR
from motordefintions import BoosterMotor,SustainerMotor

# %%
JUMPStack.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 8.985 kg (without motor)
# Rocket Dry Mass: 8.985 kg (with unloaded motor)
# Rocket Loaded Mass: 13.478 kg
# Rocket Structural Mass Ratio: 0.667
# Rocket Inertia (with unloaded motor) 11: 4.165 kg*m2
# Rocket Inertia (with unloaded motor) 22: 4.165 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.008 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.027 m
# Rocket Frontal Area: 0.002290 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.000 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.484 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.844 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.282 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 11.776/rad
# Tail Lift Coefficient Derivative: 0.766/rad
# Fins Lift Coefficient Derivative: 28.809/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: -0.183 m
# Fins Center of Pressure position: -1.484 m
# Tail Center of Pressure position: -1.508 m
# Fins Center of Pressure position: -2.983 m
#
# Stability
#
# Center of Mass position (time=0): -1.845 m
# Center of Pressure position (time=0): -2.420 m
# Initial Static Margin (mach=0, time=0): 10.653 c
# Final Static Margin (mach=0, time=burn_out): 15.866 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.575 m
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %%
JUMPSustainer.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 2.950 kg (without motor)
# Rocket Dry Mass: 2.950 kg (with unloaded motor)
# Rocket Loaded Mass: 4.968 kg
# Rocket Structural Mass Ratio: 0.594
# Rocket Inertia (with unloaded motor) 11: 0.342 kg*m2
# Rocket Inertia (with unloaded motor) 22: 0.342 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.004 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.027 m
# Rocket Frontal Area: 0.002290 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.000 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.984 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.541 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.220 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 11.776/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: -0.183 m
# Fins Center of Pressure position: -1.484 m
#
# Stability
#
# Center of Mass position (time=0): -0.887 m
# Center of Pressure position (time=0): -1.295 m
# Initial Static Margin (mach=0, time=0): 7.560 c
# Final Static Margin (mach=0, time=burn_out): 11.632 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.408 m
#
#
# Parachute Details
#
# Parachute Main with a cd_s of 0.5251 m2
# Ejection signal trigger: 800 m (AGL)
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 1.5 s
#
#
# Parachute Details
#
# Parachute Drogue with a cd_s of 0.0081 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 1.5 s
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %%
JUMPSustainerNOMOTOR.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 4.968 kg (without motor)
# Rocket Dry Mass: 4.968 kg (with unloaded motor)
# Rocket Loaded Mass: 4.968 kg
# Rocket Structural Mass Ratio: 1.000
# Rocket Inertia (with unloaded motor) 11: 0.217 kg*m2
# Rocket Inertia (with unloaded motor) 22: 0.217 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.002 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.027 m
# Rocket Frontal Area: 0.002290 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.000 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.667 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.667 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.000 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 11.776/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: -0.183 m
# Fins Center of Pressure position: -1.484 m
#
# Stability
#
# Center of Mass position (time=0): -0.667 m
# Center of Pressure position (time=0): -1.295 m
# Initial Static Margin (mach=0, time=0): 11.632 c
# Final Static Margin (mach=0, time=burn_out): 11.632 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.628 m
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %%
BoosterMotor.draw()
BoosterMotor.info()

SustainerMotor.draw()
SustainerMotor.info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.025 m
# Nozzle Throat Radius: 0.0165 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0.001 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.027 m
# Grain Inner Radius: 0.00827535936523572 m
# Grain Height: 1.193 m
# Grain Volume: 0.002 m3
# Grain Mass: 4.493 kg
#
# Motor Details
# Total Burning Time: 3.545 s
# Total Propellant Mass: 4.493 kg
# Structural Mass Ratio: 0.000
# Average Propellant Exhaust Velocity: 2007.608 m/s
# Average Thrust: 2544.571 N
# Maximum Thrust: 4918.216 N at 0.041 s after ignition.
# Total Impulse: 9020.504 Ns
# Nozzle Details
# Nozzle Radius: 0.025 m
# Nozzle Throat Radius: 0.0165 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0.001 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.0238 m
# Grain Inner Radius: 0.010803316353674219 m
# Grain Height: 0.787 m
# Grain Volume: 0.001 m3
# Grain Mass: 2.018 kg
#
# Motor Details
# Total Burning Time: 1.795 s
# Total Propellant Mass: 2.018 kg
# Structural Mass Ratio: 0.000
# Average Propellant Exhaust Velocity: 2227.956 m/s
# Average Thrust: 2504.918 N
# Maximum Thrust: 3991.7496 N at 1.106 s after ignition.
# Total Impulse: 4496.329 Ns
