# %%
import numpy as np
from matplotlib import pyplot as plt
from ambiance import Atmosphere
import pandas as pd

flightprofilepath = "twostageflightdata.CSV"

flightdata = pd.read_csv(flightprofilepath)

print(flightdata.columns)
